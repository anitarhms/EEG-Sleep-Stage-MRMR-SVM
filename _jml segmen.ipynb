# %%
import pandas as pd
import numpy as np

# %%
fitur = pd.DataFrame([])  #membuat dataframe 
FILE_PATH = '/content/drive/MyDrive/csv fitur/subband baru/11.csv' #path file csv dalam satu folder, pakai looping for i in range agar bacanya urut 
data = pd.read_csv(FILE_PATH, sep=",", header=0) #read csv, berdasarkan path, row 0 sbg header 

print(data)
# Out:
#       class          f1         f2  ...       f30        f31        f32
# 0         1  100.739441  30.685402  ...  0.174945  29.218492  22.798497
# 1         1   85.442119  23.385984  ... -0.453723  24.702483  17.809772
# 2         1   56.429322  19.354219  ...  0.022214  18.034145  13.710996
# 3         1   90.771450  39.787294  ... -0.104445  30.238912  19.874964
# 4         1   61.504749  22.247866  ... -0.192263  20.200911  14.817820
# ...     ...         ...        ...  ...       ...        ...        ...
# 2751      1   39.458458  17.707671  ...  1.447036  13.858376  10.298096
# 2752      1   47.421796  21.564318  ...  0.727066  17.272902  12.008964
# 2753      1   44.787647  18.344150  ... -0.201333  14.601041   9.467959
# 2754      1   19.300815  10.975899  ...  0.270798   8.410209   6.680703
# 2755      1   41.886231  19.494902  ...  0.354108  13.360366   8.679322
#
# [2756 rows x 33 columns]

# %%
data=data.rename(columns={'class': 'Anotasi'})

# %%
wake=data[data.Anotasi == 1]
ls=data[data.Anotasi == 2]
ds=data[data.Anotasi == 3]
print(wake)
print(ls)
print(ds)
# Out:
#       Anotasi          f1         f2  ...       f30        f31        f32
# 0           1  100.739441  30.685402  ...  0.174945  29.218492  22.798497
# 1           1   85.442119  23.385984  ... -0.453723  24.702483  17.809772
# 2           1   56.429322  19.354219  ...  0.022214  18.034145  13.710996
# 3           1   90.771450  39.787294  ... -0.104445  30.238912  19.874964
# 4           1   61.504749  22.247866  ... -0.192263  20.200911  14.817820
# ...       ...         ...        ...  ...       ...        ...        ...
# 2751        1   39.458458  17.707671  ...  1.447036  13.858376  10.298096
# 2752        1   47.421796  21.564318  ...  0.727066  17.272902  12.008964
# 2753        1   44.787647  18.344150  ... -0.201333  14.601041   9.467959
# 2754        1   19.300815  10.975899  ...  0.270798   8.410209   6.680703
# 2755        1   41.886231  19.494902  ...  0.354108  13.360366   8.679322
#
# [1939 rows x 33 columns]
# ...

# %%
len(wake)+len(ls)+len(ds)
# Out:
# 2756
